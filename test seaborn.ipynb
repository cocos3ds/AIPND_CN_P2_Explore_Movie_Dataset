# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

test_dict = {"popularity":[1.8,1.2,3,2.2,1.2,3.2,5],"revenue":[1,2,3,2,4,5,6],
             "original_title":["movie 1","movie 1","movie 2","movie 3","movie 3","movie 4","movie 5"]}
movie_data = pd.DataFrame(test_dict)
#sns.barplot(x="original_title",y="popularity",data = movie_data)
movie_data.sort_values(by='popularity',axis=0,ascending=True)
# Out:
#    popularity  revenue original_title
# 1         1.2        2        movie 1
# 4         1.2        4        movie 3
# 0         1.8        1        movie 1
# 3         2.2        2        movie 3
# 2         3.0        3        movie 2
# 5         3.2        5        movie 4
# 6         5.0        6        movie 5

# %%
movie_data['newcolumn'] = movie_data['popularity'] + 2

# %%
movie_data
# Out:
#    popularity  revenue original_title  newcolumn
# 0         1.8        1        movie 1        3.8
# 1         1.2        2        movie 1        3.2
# 2         3.0        3        movie 2        5.0
# 3         2.2        2        movie 3        4.2
# 4         1.2        4        movie 3        3.2
# 5         3.2        5        movie 4        5.2
# 6         5.0        6        movie 5        7.0

# %%
new_data = movie_data.groupby('original_title').agg('sum')
new_data
# Out:
#                 popularity  revenue  newcolumn
# original_title
# movie 1                3.0        3        7.0
# movie 2                3.0        3        5.0
# movie 3                3.4        6        7.4
# movie 4                3.2        5        5.2
# movie 5                5.0        6        7.0

# %%
new_data['pn'] = new_data['popularity']+new_data['newcolumn']
new_data
# Out:
#                 popularity  revenue  newcolumn    pn
# original_title
# movie 1                3.0        3        7.0  10.0
# movie 2                3.0        3        5.0   8.0
# movie 3                3.4        6        7.4  10.8
# movie 4                3.2        5        5.2   8.4
# movie 5                5.0        6        7.0  12.0

# %%
result = new_data.reset_index()
result
# type(index_data)
# print(index_data)
# sns.barplot(x=index_data,y="pn",data = new_data)
# Out:
#   original_title  popularity  revenue  newcolumn    pn
# 0        movie 1         3.0        3        7.0  10.0
# 1        movie 2         3.0        3        5.0   8.0
# 2        movie 3         3.4        6        7.4  10.8
# 3        movie 4         3.2        5        5.2   8.4
# 4        movie 5         5.0        6        7.0  12.0

# %%
movie_data.isnull().any(axis=1)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
item = pd.Series(data=[1,2,3,4,5],index=['a','b','c','d','e'])

# %%
item_dict = {'ben':[2,3,4,2,1]}
pd.DataFrame(item_dict)
# Out:
#    ben
# 0    2
# 1    3
# 2    4
# 3    2
# 4    1
